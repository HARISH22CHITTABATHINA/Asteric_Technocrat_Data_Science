# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('Instagram-Reach.csv') #reading data from csv file
df.head() # display first few rows
# Out:
#                   Date  Instagram reach
# 0  2022-04-01T00:00:00             7620
# 1  2022-04-02T00:00:00            12859
# 2  2022-04-03T00:00:00            16008
# 3  2022-04-04T00:00:00            24349
# 4  2022-04-05T00:00:00            20532

# %%
df.head(10) # display first 10 rows
# Out:
#                   Date  Instagram reach
# 0  2022-04-01T00:00:00             7620
# 1  2022-04-02T00:00:00            12859
# 2  2022-04-03T00:00:00            16008
# 3  2022-04-04T00:00:00            24349
# 4  2022-04-05T00:00:00            20532
# 5  2022-04-06T00:00:00            19408
# 6  2022-04-07T00:00:00            14941
# 7  2022-04-08T00:00:00            17263
# 8  2022-04-09T00:00:00            20224
# 9  2022-04-10T00:00:00            30471

# %%
df.tail() # display last few rows
# Out:
#                     Date  Instagram reach
# 360  2023-03-27T00:00:00            15622
# 361  2023-03-28T00:00:00            18645
# 362  2023-03-29T00:00:00            41238
# 363  2023-03-30T00:00:00            50490
# 364  2023-03-31T00:00:00            22014

# %%
df.tail(10) # display last 10 rows
# Out:
#                     Date  Instagram reach
# 355  2023-03-22T00:00:00            18075
# 356  2023-03-23T00:00:00            16319
# 357  2023-03-24T00:00:00            15612
# 358  2023-03-25T00:00:00            21229
# 359  2023-03-26T00:00:00            16080
# 360  2023-03-27T00:00:00            15622
# 361  2023-03-28T00:00:00            18645
# 362  2023-03-29T00:00:00            41238
# 363  2023-03-30T00:00:00            50490
# 364  2023-03-31T00:00:00            22014

# %%
df.shape # to get dimensions
# Out:
# (365, 2)

# %%
len(df) # to display no of rows
# Out:
# 365

# %%
df.describe() # to generate summary statistics
# Out:
#        Instagram reach
# count       365.000000
# mean      50474.712329
# std       30051.787552
# min        7620.000000
# 25%       25070.000000
# 50%       43987.000000
# 75%       68331.000000
# max      161998.000000

# %%
df.info() # display information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             365 non-null    object
#  1   Instagram reach  365 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 5.8+ KB

# %%
df.columns # to get column names
# Out:
# Index(['Date', 'Instagram reach'], dtype='object')

# %%
df.dtypes # to get the datatypes
# Out:
# Date               object
# Instagram reach     int64
# dtype: object

# %%
df.isnull().sum() # implies no null values
# Out:
# Date               0
# Instagram reach    0
# dtype: int64

# %%
df.dropna() # return new data frame with no empty cell

print(df.to_string())
# Out:
#                     Date  Instagram reach
# 0    2022-04-01T00:00:00             7620
# 1    2022-04-02T00:00:00            12859
# 2    2022-04-03T00:00:00            16008
# 3    2022-04-04T00:00:00            24349
# 4    2022-04-05T00:00:00            20532
# 5    2022-04-06T00:00:00            19408
# 6    2022-04-07T00:00:00            14941
# 7    2022-04-08T00:00:00            17263
# 8    2022-04-09T00:00:00            20224
# 9    2022-04-10T00:00:00            30471
# 10   2022-04-11T00:00:00            39774
# 11   2022-04-12T00:00:00            43550
# 12   2022-04-13T00:00:00            42342
# 13   2022-04-14T00:00:00            55477
# 14   2022-04-15T00:00:00            54391
# 15   2022-04-16T00:00:00            44108
# 16   2022-04-17T00:00:00            49089
# 17   2022-04-18T00:00:00            42790
# 18   2022-04-19T00:00:00            49940
# 19   2022-04-20T00:00:00            45763
# 20   2022-04-21T00:00:00            38457
# ...

# %%
plt.figure(figsize=(10, 8))
plt.style.use('fivethirtyeight')
plt.title("Distribution of Impressions Instagram reach")
sns.histplot(df['Instagram reach'])
plt.show()

# %%
date_column = df['Date'].value_counts().head(10)
reach_column = df['Instagram reach'].value_counts().head(10)

# Create a bar graph
plt.bar(date_column.index, date_column.values)  # Use .index and .values

# Add labels and a title
plt.xlabel('Date')
plt.ylabel('Instagram reach')
plt.title('Bar Graph')

# Rotate the x-axis labels for better readability if needed
plt.xticks(rotation=45)

# Display the graph
plt.show()
